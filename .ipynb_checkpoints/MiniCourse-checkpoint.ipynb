# %% [markdown]
# Understand Data with Descriptive Statistics

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'

# %%
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']

# %%
data = pd.read_csv(url, names=names)

# %%
description = data.describe()

# %%
description
# Out:
#              preg        plas        pres        skin        test        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# 50%      0.372500   29.000000    0.000000
# 75%      0.626250   41.000000    1.000000
# max      2.420000   81.000000    1.000000

# %%
scatter_matrix(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b3868f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b3d26518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b3862710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b37c7cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b3c4f2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b3c6f860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b3c13e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b3c3d438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b3c3d470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b3bfff60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b3911550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b3931b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b38dc0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b387d6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b389fc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b3809240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b382a7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b178cda0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1736390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1756940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b16f9ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b17254e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b16caa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1686080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1635630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1666be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b16251d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b15d4780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1587d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1544320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b14f28d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1525e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b14e1470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b148fa20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1443fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b13ff5c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1431b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b13ed160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b139d710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b134dcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b130b2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b12bc860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b12eee10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b12a8358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b125a908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b120beb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b11c84a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1178a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1137048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b11645f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1114ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b10d4198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1083748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1035cf8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0ff42e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b1022898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0fd3e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0f8f438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0f419e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0ef2f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0f2e588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0edfb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0e9c128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0e4c6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0dfec88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0dbc278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0dea828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0d9cdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0d593c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0d08978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0cbaf28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0c76518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0ca9ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0c660b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0c14668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0bc6c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0b82208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0b337b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0b65d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0b22358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb7b0ad0908>]],
#       dtype=object)

# %%
plt.show()

# %%
array = data.values

# %%
array
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
x = array[:,:8]

# %%
y = array[:,8]

# %%
scaler = StandardScaler().fit(x)

# %%
rescaledX = scaler.transform(x)

# %%
np.set_printoptions(precision=3)

# %%
rescaledX[0:5,:]
# Out:
# array([[ 0.64 ,  0.848,  0.15 ,  0.907, -0.693,  0.204,  0.468,  1.426],
#        [-0.845, -1.123, -0.161,  0.531, -0.693, -0.684, -0.365, -0.191],
#        [ 1.234,  1.944, -0.264, -1.288, -0.693, -1.103,  0.604, -0.106],
#        [-0.845, -0.998, -0.161,  0.155,  0.123, -0.494, -0.921, -1.042],
#        [-1.142,  0.504, -1.505,  0.907,  0.766,  1.41 ,  5.485, -0.02 ]])

# %%
kfold = KFold(n_splits=10, random_state=7)
# Out:
# /home/rahul/Workspace/spograde-recommendation-engine/venv/lib/python3.6/site-packages/scikit_learn-0.22-py3.6-linux-x86_64.egg/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %%
model = LogisticRegression(solver='liblinear')

# %%
results = cross_val_score(model, x, y, cv=kfold)

# %%
"Accuracy {} {}".format(results.mean() * 100.0, results.std() * 100.0)
# Out:
# 'Accuracy 76.95146958304852 4.841051924567195'

# %% [markdown]
# ### Improve accuracy with algorithm tunning

# %%
alphas = np.array([1,0.1,0.01,0.001,0.0001,0])

# %%
param_grid = dict(alphas=alphas)

# %%
model = Ridge()

# %%
grid = Gr
